# %%
! pip install -U deepeval
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.3/565.3 kB 14.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 20.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 29.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 67.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.1 MB/s eta 0:00:00
# ...

# %%
# !pip install colab-xterm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.6/115.6 kB 5.5 MB/s eta 0:00:00
# ...

# %%
# %load_ext colabxterm

# %%
# %xterm
# Out:
# Launching Xterm...

# %%
# !ollama run deepseek-r1:1.5b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling aabd4debf0c8...   0% ▕▏    0 B/1.1 GB                  pulling manifest
# pulling aabd4debf0c8...   0% ▕▏    0 B/1.1 GB                  pulling manifest
# pulling aabd4debf0c8...   0% ▕▏ 448 KB/1.1 GB                  pulling manifest
# pulling aabd4debf0c8...   4% ▕▏  48 MB/1.1 GB                  pulling manifest
# pulling aabd4debf0c8...   6% ▕▏  67 MB/1.1 GB                  pulling manifest
# pulling aabd4debf0c8...  12% ▕▏ 138 MB/1.1 GB                  pulling manifest
# pulling aabd4debf0c8...  15% ▕▏ 168 MB/1.1 GB                  pulling manifest
# pulling aabd4debf0c8...  16% ▕▏ 182 MB/1.1 GB                  pulling manifest
# pulling aabd4debf0c8...  21% ▕▏ 229 MB/1.1 GB                  pulling manifest
# pulling aabd4debf0c8...  24% ▕▏ 265 MB/1.1 GB                  pulling manifest
# ...

# %%
! pip install ollama

# %%
# !deepeval login
# Out:
# Welcome to ✨DeepEval✨!
# Login and grab your API key here: ]8;id=719324;https://app.confident-ai.com/pair?code=HFEHA3&port=34705\https://app.confident-ai.com/pair?]8;;\]8;id=396514;https://app.confident-ai.com/pair?code=HFEHA3&port=34705\code]8;;\]8;id=719324;https://app.confident-ai.com/pair?code=HFEHA3&port=34705\=]8;;\]8;id=996036;https://app.confident-ai.com/pair?code=HFEHA3&port=34705\HFEHA3]8;;\]8;id=719324;https://app.confident-ai.com/pair?code=HFEHA3&port=34705\&]8;;\]8;id=396514;https://app.confident-ai.com/pair?code=HFEHA3&port=34705\port]8;;\]8;id=719324;https://app.confident-ai.com/pair?code=HFEHA3&port=34705\=]8;;\]8;id=996036;https://app.confident-ai.com/pair?code=HFEHA3&port=34705\34705]8;;\
# Paste your API Key: IuL/cvSbvVDhxt6kIZZCy8g3vspSAbSsBNdlgA7a+Bo=
#
# 🎉🥳 Congratulations! You've successfully logged in! 🙌
# You're now using DeepEval with Confident AI. Follow our quickstart tutorial here:
# ...

# %%
# !pip install llama-index

# %%
! deepeval set-ollama deepseek-r1:1.5b
# Out:
# 🙌 Congratulations! You're now using a local Ollama model for all evals that require an LLM.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741713589.235378    2176 init.cc:232] grpc_wait_for_shutdown_with_timeout() timed out.

# %%
import json
# evaluation metrics
from deepeval import evaluate
from deepeval.metrics import AnswerRelevancyMetric, FaithfulnessMetric, ContextualRelevancyMetric
from deepeval.test_case import LLMTestCase

# %%
# load test cases from JSON
with open("test_cases.json", "r") as f:
    test_cases_data = json.load(f)

# convert dictionaries back to LLMTestCase objects
loaded_test_cases = [LLMTestCase(**data) for data in test_cases_data]

print("Test cases loaded successfully!")
# Out:
# Test cases loaded successfully!

# %%
# !deepeval login
# Out:
# Welcome to ✨DeepEval✨!
# Login and grab your API key here: ]8;id=827498;https://app.confident-ai.com/pair?code=FD42RA&port=34121\https://app.confident-ai.com/pair?]8;;\]8;id=593522;https://app.confident-ai.com/pair?code=FD42RA&port=34121\code]8;;\]8;id=827498;https://app.confident-ai.com/pair?code=FD42RA&port=34121\=]8;;\]8;id=197893;https://app.confident-ai.com/pair?code=FD42RA&port=34121\FD42RA]8;;\]8;id=827498;https://app.confident-ai.com/pair?code=FD42RA&port=34121\&]8;;\]8;id=593522;https://app.confident-ai.com/pair?code=FD42RA&port=34121\port]8;;\]8;id=827498;https://app.confident-ai.com/pair?code=FD42RA&port=34121\=]8;;\]8;id=197893;https://app.confident-ai.com/pair?code=FD42RA&port=34121\34121]8;;\
# Paste your API Key: IuL/cvSbvVDhxt6kIZZCy8g3vspSAbSsBNdlgA7a+Bo=
#
# 🎉🥳 Congratulations! You've successfully logged in! 🙌
# You're now using DeepEval with Confident AI. Follow our quickstart tutorial here:
# ...

# %%
# make objects on relevant metrics
answer_relevancy = AnswerRelevancyMetric()
faithfulness = FaithfulnessMetric()
contextual_relevancy = ContextualRelevancyMetric()

# %%
evaluate(test_cases=loaded_test_cases, metrics=[answer_relevancy, faithfulness, contextual_relevancy], identifier="v1.2")
# Out:
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using YES (Ollama), strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Faithfulness Metric! (using YES (Ollama), strict=False, async_mode=True)...
# ✨ You're running DeepEval's latest Contextual Relevancy Metric! (using YES (Ollama), strict=False,
# async_mode=True)...
# Event loop is already running. Applying nest_asyncio patch to allow async execution...
# Evaluating 43 test case(s) in parallel: |██████████|100% (43/43) [Time Taken: 11:14, 15.69s/test case]
# ...
#
# Metrics Summary
#
#   - ❌ Answer Relevancy (score: 0.0, threshold: 0.5, strict: False, evaluation model: YES (Ollama), reason: The answer must address the question provided in the input, but it doesn't do so because... Please provide a detailed response., error: None)
# ...
